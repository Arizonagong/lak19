# %%
import pandas as pd
pd.options.display.float_format = '{:20,.0f}'.format

# %%
pop = pd.read_csv('data/countrypop.csv')

# %%
pop
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
pop.T
# Out:
#                               0                    1                    2    \
# Country Name                Aruba          Afghanistan               Angola
# Country Code                  ABW                  AFG                  AGO
# 1960                       54,211            8,996,351            5,643,182
# 1961                       55,438            9,166,764            5,753,024
# 1962                       56,225            9,345,868            5,866,061
# 1963                       56,695            9,533,954            5,980,417
# 1964                       57,032            9,731,361            6,093,321
# 1965                       57,360            9,938,414            6,203,299
# 1966                       57,715           10,152,331            6,309,770
# 1967                       58,055           10,372,630            6,414,995
# 1968                       58,386           10,604,346            6,523,791
# ...
